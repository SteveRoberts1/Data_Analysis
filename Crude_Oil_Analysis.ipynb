# %%
#Uploading the dataset into google collab

from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-e5ac321e-135c-4a80-ac7d-8733c3098c1f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5ac321e-135c-4a80-ac7d-8733c3098c1f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("DP_LIVE_18112023172152402.csv", encoding='latin-1')
data.head()
# Out:
#   ï»¿Country  Year  Value (KTOE)
# 0        AUS  2000    25081.1572
# 1        AUS  2001    26611.8285
# 2        AUS  2002    30307.7115
# 3        AUS  2003    29403.1762
# 4        AUS  2004    25785.0349

# %%
# !pip install pycountry
import pycountry

data['Country Name'] = data['ï»¿Country'].map(lambda code: pycountry.countries.get(alpha_3=code).name if pycountry.countries.get(alpha_3=code) else code)
data.head()
# Out:
#   ï»¿Country  Year  Value (KTOE) Country Name
# 0        AUS  2000    25081.1572    Australia
# 1        AUS  2001    26611.8285    Australia
# 2        AUS  2002    30307.7115    Australia
# 3        AUS  2003    29403.1762    Australia
# 4        AUS  2004    25785.0349    Australia

# %%
# Define a function to convert units
def convert_to_BOE(value):
    conversion_factor = 7.33
    return (value * 1000) * conversion_factor

# Apply the function to create a new column
data['Values (BOE)'] = data['Value (KTOE)'].apply(convert_to_BOE)
data.head()
# Out:
#   Country  Year  Value (KTOE) Country Name  Values (BOE)
# 0     AUS  2000    25081.1572    Australia  1.838449e+08
# 1     AUS  2001    26611.8285    Australia  1.950647e+08
# 2     AUS  2002    30307.7115    Australia  2.221555e+08
# 3     AUS  2003    29403.1762    Australia  2.155253e+08
# 4     AUS  2004    25785.0349    Australia  1.890043e+08

# %%
csv_filename = 'Oil Production per Country Edit.csv'
df.to_csv(csv_filename, index=False)

# Download the CSV file
from google.colab import files
files.download(csv_filename)
